# %%
baseball	return
[[123, 1, 1], [356, 1, 0], [327, 2, 0], [489, 0, 1]]	2
# Out:
#   File "<ipython-input-1-97a88be2a7c2>", line 1
#     baseball	return
#             	     ^
# SyntaxError: invalid syntax

# %%
import re

# %%
b = [["123", 1, 1], ["356", 1, 0], ["327", 2, 0], ["489", 0, 1]]

# %%
l = []
for i in range(1,10):
    for j in range(1,10):
        for k in range(1,10):
            if i!=j and j!=k and k!=i:
                now = str(i)+str(j)+str(k)
                l.append([now,False])
for now in b:
    if now[1] == 3:
        answer = 1
        break
    
    elif now[1] == 2:
        nows = now[0]
        temp1 = f"[^{nows[0]}]"+nows[1]+nows[2]
        temp2 = nows[0]+f"[^{nows[1]}]"+nows[2]
        temp3 = nows[0]+nows[1]+f"[^{nows[2]}]"
        for t in l:
            for i in range(1,4):
                nowv = "temp"+str(i)
                if re.match(globals()[nowv],t[0]):
                    t[1]=True
                    
    elif now[1] == 1 and now[2] == 2:
        nows = now[0]
        temp1 = nows[0]+now[2]+f"[^{nows[1]}]"
        temp2 = nows[0]+f"[^{nows[2]}]"+now[1]
        
    
    elif now[1] == 1 and now[2] == 1:
                    
    elif now[1] == 1:
        nows = now[0]
        temp1 = f"[^{nows[0]}|^{nows[1]}]"+f"[^{nows[0]}|^{nows[1]}]"+nows[2]
        temp2 = nows[0]+f"[^{nows[1]}|^{nows[2]}]"+f"[^{nows[1]}|^{nows[2]}]"
        temp3 = f"[^{nows[0]}|^{nows[2]}]"+nows[1]+f"[^{nows[0]}|^{nows[2]}]"
        for t in l:
            for i in range(1,4):
                nowv = "temp"+str(i)
                if re.match(globals()[nowv],t[0]):
                    t[1]=True
    
    
    
    elif now[2] == 3:
        nows = now[0]
        temp1 = nows[1]+nows[0]+nows[2]
        temp2 = nows[1]+nows[2]+nows[0]
        temp3 = nows[2]+nows[1]+nows[0]
        temp4 = nows[2]+nows[0]+nows[1]
        temp5 = nows[0]+nows[2]+nows[1]
        for t in l:
            for i in range(1,6):
                nowv = "temp"+str(i)
                if re.match(globals()[nowv],t[0]):
                    t[1]=True
                    
    elif now[2] == 2:
        nows = now[0]
        temp1 = f"[^{nows[2]}]"+nows[0]+nows[1]
        temp2 = f"[^{nows[2]}]"+nows[1]+nows[0]
        temp3 = f"[^{nows[0]}]"+nows[2]+nows[1]
        temp4 = nows[1]+f"[^{nows[2]}]"+nows[0]
        temp5 = nows[2]+f"[^{nows[1]}]"+nows[0]
        temp6 = nows[2]+f"[^{nows[0]}]"+nows[1]
        temp7 = nows[1]+nows[2]+f"[^{nows[0]}]"
        temp8 = nows[1]+nows[0]+f"[^{nows[2]}]"
        temp9 = nows[2]+nows[0]+f"[^{nows[1]}]"
        for t in l:
            for i in range(1,10):
                nowv = "temp"+str(i)
                if re.match(globals()[nowv],t[0]):
                    t[1]=True
                    
    elif now[2] == 1:
        nows = now[0]
        temp1 = nows[1]+f"[^{nows[0]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[2]}]"
        temp2 = nows[2]+f"[^{nows[0]}|^{nows[1]}]"+f"[^{nows[0]}|^{nows[1]}]"
        temp3 = f"[^{nows[1]}|^{nows[2]}]"+nows[0]+f"[^{nows[1]}|^{nows[2]}]"
        temp4 = f"[^{nows[0]}|^{nows[1]}]"+nows[2]+f"[^{nows[0]}|^{nows[1]}]"
        temp5 = f"[^{nows[1]}|^{nows[2]}]"+f"[^{nows[1]}|^{nows[2]}]"+nows[0]
        temp6 = f"[^{nows[0]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[2]}]"+nows[1]
        for t in l:
            for i in range(1,7):
                nowv = "temp"+str(i)
                if re.match(globals()[nowv],t[0]):
                    t[1]=True
                    
    elif now[1] == 0 and now[2] == 0:
        nows = now[0]
        temp = f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"
        if re.match(temp,t[0]):
            t[1] = True
            
    nl = []
    for i in l:
        if i[1]:
            nl.append([i[0],False])
    l = nl
# Out:
# [['145', False], ['146', False], ['147', False], ['148', False], ['149', False], ['154', False], ['156', False], ['157', False], ['158', False], ['159', False], ['164', False], ['165', False], ['167', False], ['168', False], ['169', False], ['174', False], ['175', False], ['176', False], ['178', False], ['179', False], ['184', False], ['185', False], ['186', False], ['187', False], ['189', False], ['194', False], ['195', False], ['196', False], ['197', False], ['198', False], ['425', False], ['426', False], ['427', False], ['428', False], ['429', False], ['453', False], ['463', False], ['473', False], ['483', False], ['493', False], ['524', False], ['526', False], ['527', False], ['528', False], ['529', False], ['543', False], ['563', False], ['573', False], ['583', False], ['593', False], ['624', False], ['625', False], ['627', False], ['628', False], ['629', False], ['643', False], ['653', False], ['673', False], ['683', False], ['693', False], ['724', False], ['725', False], ['726
# ...

# %%
for t in l:
    p = re.findall("32.",t)
    l

# %%
now = b[0]
nows = now[0]
temp = "."+nows[1]+nows[2]

# %%
now = b[0]
nows = now[0]
temp = f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+"{1}"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]{1}"+"{1}"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+"{1}"
if re.match(temp,t[0]):
    t[1] = True
l
# Out:
# [['123', False],
#  ['124', False],
#  ['125', False],
#  ['126', False],
#  ['127', False],
#  ['128', False],
#  ['129', False],
#  ['132', False],
#  ['134', False],
#  ['135', False],
#  ['136', False],
#  ['137', False],
#  ['138', False],
#  ['139', False],
#  ['142', False],
#  ['143', False],
#  ['145', False],
#  ['146', False],
#  ['147', False],
#  ['148', False],
#  ['149', False],
#  ['152', False],
#  ['153', False],
#  ['154', False],
#  ['156', False],
#  ['157', False],
#  ['158', False],
#  ['159', False],
#  ['162', False],
#  ['163', False],
#  ['164', False],
#  ['165', False],
#  ['167', False],
#  ['168', False],
#  ['169', False],
#  ['172', False],
#  ['173', False],
#  ['174', False],
#  ['175', False],
#  ['176', False],
#  ['178', False],
#  ['179', False],
#  ['182', False],
#  ['183', False],
#  ['184', False],
#  ['185', False],
#  ['186', False],
#  ['187', False],
#  ['189', False],
#  ['192', False],
#  ['193', False],
#  ['194', False],
# ...

# %%
now = b[0]
nows = now[0]
temp1 = nows[0]+f"[^{nows[1]}|^{nows[2]}]"+f"[^{nows[1]}|^{nows[2]}]"
for t in l:
    if re.match(temp1,t[0]):
        t[1]=True
l

# %%
nl = []
for i in l:
    if i[1]:
        nl.append([i[0],False])
nl

# %%
i = 1
if i:
    print(t)

# %%
l = []
for i in range(1,10):
    for j in range(1,10):
        for k in range(1,10):
            if i!=j and j!=k and k!=i:
                now = str(i)+str(j)+str(k)
                l.append([now,False])
l
# Out:
# [['123', False],
#  ['124', False],
#  ['125', False],
#  ['126', False],
#  ['127', False],
#  ['128', False],
#  ['129', False],
#  ['132', False],
#  ['134', False],
#  ['135', False],
#  ['136', False],
#  ['137', False],
#  ['138', False],
#  ['139', False],
#  ['142', False],
#  ['143', False],
#  ['145', False],
#  ['146', False],
#  ['147', False],
#  ['148', False],
#  ['149', False],
#  ['152', False],
#  ['153', False],
#  ['154', False],
#  ['156', False],
#  ['157', False],
#  ['158', False],
#  ['159', False],
#  ['162', False],
#  ['163', False],
#  ['164', False],
#  ['165', False],
#  ['167', False],
#  ['168', False],
#  ['169', False],
#  ['172', False],
#  ['173', False],
#  ['174', False],
#  ['175', False],
#  ['176', False],
#  ['178', False],
#  ['179', False],
#  ['182', False],
#  ['183', False],
#  ['184', False],
#  ['185', False],
#  ['186', False],
#  ['187', False],
#  ['189', False],
#  ['192', False],
#  ['193', False],
#  ['194', False],
# ...

# %%
temp
# Out:
# '[^1|^2|^3][^1|^2|^3][^1|^2|^3]'

# %%
nows = "123"
temp = f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"+f"[^{nows[0]}|^{nows[1]}|^{nows[2]}]"
for t in l:
    if re.match(temp,t[0]):
        t[1]=True
l
# Out:
# [['123', False],
#  ['124', False],
#  ['125', False],
#  ['126', False],
#  ['127', False],
#  ['128', False],
#  ['129', False],
#  ['132', False],
#  ['134', False],
#  ['135', False],
#  ['136', False],
#  ['137', False],
#  ['138', False],
#  ['139', False],
#  ['142', False],
#  ['143', False],
#  ['145', False],
#  ['146', False],
#  ['147', False],
#  ['148', False],
#  ['149', False],
#  ['152', False],
#  ['153', False],
#  ['154', False],
#  ['156', False],
#  ['157', False],
#  ['158', False],
#  ['159', False],
#  ['162', False],
#  ['163', False],
#  ['164', False],
#  ['165', False],
#  ['167', False],
#  ['168', False],
#  ['169', False],
#  ['172', False],
#  ['173', False],
#  ['174', False],
#  ['175', False],
#  ['176', False],
#  ['178', False],
#  ['179', False],
#  ['182', False],
#  ['183', False],
#  ['184', False],
#  ['185', False],
#  ['186', False],
#  ['187', False],
#  ['189', False],
#  ['192', False],
#  ['193', False],
#  ['194', False],
# ...

# %%
temp1
# Out:
# '2[^1|^3][^1|^3]'
